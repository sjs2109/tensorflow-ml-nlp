# %% [markdown]
# # 패키지 불러오기

# %%
# !rm configs.py
# !rm data.py
# !rm main.py
# !rm model.py
# !rm predict.py



# !wget https://raw.githubusercontent.com/sjs2109/tensorflow-ml-nlp/master/6.CHATBOT/6.4%20transformer/configs.py .
# !wget https://raw.githubusercontent.com/sjs2109/tensorflow-ml-nlp/master/6.CHATBOT/6.4%20transformer/data.py
# !wget https://raw.githubusercontent.com/sjs2109/tensorflow-ml-nlp/master/6.CHATBOT/6.4%20transformer/model.py
# !wget https://raw.githubusercontent.com/sjs2109/tensorflow-ml-nlp/master/6.CHATBOT/6.4%20transformer/predict.py
# Out:
# rm: cannot remove 'data.py': No such file or directory
# rm: cannot remove 'main.py': No such file or directory
# --2019-03-27 01:24:06--  https://raw.githubusercontent.com/sjs2109/tensorflow-ml-nlp/master/6.CHATBOT/6.4%20transformer/configs.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1760 (1.7K) [text/plain]
# Saving to: ‘configs.py’
#
# configs.py          100%[===================>]   1.72K  --.-KB/s    in 0s
#
# 2019-03-27 01:24:06 (248 MB/s) - ‘configs.py’ saved [1760/1760]
#
# --2019-03-27 01:24:06--  http://./
# Resolving . (.)... failed: No address associated with hostname.
# wget: unable to resolve host address ‘.’
# FINISHED --2019-03-27 01:24:06--
# Total wall clock time: 0.09s
# Downloaded: 1 files, 1.7K in 0s (248 MB/s)
# --2019-03-27 01:24:09--  https://raw.githubusercontent.com/sjs2109/tensorflow-ml-nlp/master/6.CHATBOT/6.4%20transformer/data.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17476 (17K) [text/plain]
# Saving to: ‘data.py’
#
# data.py             100%[===================>]  17.07K  --.-KB/s    in 0.01s
#
# 2019-03-27 01:24:10 (1.40 MB/s) - ‘data.py’ saved [17476/17476]
#
# --2019-03-27 01:24:11--  https://raw.githubusercontent.com/sjs2109/tensorflow-ml-nlp/master/6.CHATBOT/6.4%20transformer/model.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6835 (6.7K) [text/plain]
# Saving to: ‘model.py’
#
# model.py            100%[===================>]   6.67K  --.-KB/s    in 0s
#
# 2019-03-27 01:24:12 (94.5 MB/s) - ‘model.py’ saved [6835/6835]
#
# --2019-03-27 01:24:14--  https://raw.githubusercontent.com/sjs2109/tensorflow-ml-nlp/master/6.CHATBOT/6.4%20transformer/predict.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2819 (2.8K) [text/plain]
# Saving to: ‘predict.py’
#
# predict.py          100%[===================>]   2.75K  --.-KB/s    in 0s
#
# 2019-03-27 01:24:14 (40.9 MB/s) - ‘predict.py’ saved [2819/2819]

# %%
# !apt-get update

# !apt-get install g++ openjdk-8-jdk python-dev python3-dev

# !pip3 install JPype1-py3

# !pip3 install konlpy

# !JAVA_HOME="/usr/lib/jvm/java-8-openjdk-amd64"

import konlpy
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease [3,609 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ Packages [58.4 kB]
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [564 B]
# Hit:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [819 B]
# Get:8 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Get:10 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:11 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:12 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [71.4 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:14 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease [15.4 kB]
# Get:15 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [31.0 kB]
# Get:16 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [361 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [725 kB]
# Get:19 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main Sources [1,627 kB]
# Get:20 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [3,910 B]
# Get:21 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [160 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [955 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [6,968 B]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-backports/universe amd64 Packages [3,659 B]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-backports/main amd64 Packages [942 B]
# Get:26 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 Packages [782 kB]
# Fetched 5,079 kB in 6s (844 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python-dev is already the newest version (2.7.15~rc1-1).
# g++ is already the newest version (4:7.3.0-3ubuntu2.1).
# g++ set to manually installed.
# python3-dev is already the newest version (3.6.7-1~18.04).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   fonts-dejavu-core fonts-dejavu-extra libatk-wrapper-java
#   libatk-wrapper-java-jni libxxf86dga1 openjdk-8-jre x11-utils
# Suggested packages:
#   openjdk-8-demo openjdk-8-source visualvm icedtea-8-plugin mesa-utils
# The following NEW packages will be installed:
#   fonts-dejavu-core fonts-dejavu-extra libatk-wrapper-java
#   libatk-wrapper-java-jni libxxf86dga1 openjdk-8-jdk openjdk-8-jre x11-utils
# 0 upgraded, 8 newly installed, 0 to remove and 127 not upgraded.
# Need to get 4,771 kB of archives.
# After this operation, 13.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxxf86dga1 amd64 2:1.1.4-1 [13.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-dejavu-core all 2.37-1 [1,041 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-dejavu-extra all 2.37-1 [1,953 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11-utils amd64 7.7+3build1 [196 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 libatk-wrapper-java all 0.33.3-20ubuntu0.1 [34.7 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 libatk-wrapper-java-jni amd64 0.33.3-20ubuntu0.1 [28.3 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 openjdk-8-jre amd64 8u191-b12-2ubuntu0.18.04.1 [69.7 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 openjdk-8-jdk amd64 8u191-b12-2ubuntu0.18.04.1 [1,435 kB]
# Fetched 4,771 kB in 3s (1,686 kB/s)
# Selecting previously unselected package libxxf86dga1:amd64.
# (Reading database ... 131323 files and directories currently installed.)
# Preparing to unpack .../0-libxxf86dga1_2%3a1.1.4-1_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.4-1) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../1-fonts-dejavu-core_2.37-1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../2-fonts-dejavu-extra_2.37-1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-1) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../3-x11-utils_7.7+3build1_amd64.deb ...
# Unpacking x11-utils (7.7+3build1) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../4-libatk-wrapper-java_0.33.3-20ubuntu0.1_all.deb ...
# Unpacking libatk-wrapper-java (0.33.3-20ubuntu0.1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../5-libatk-wrapper-java-jni_0.33.3-20ubuntu0.1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.33.3-20ubuntu0.1) ...
# Selecting previously unselected package openjdk-8-jre:amd64.
# Preparing to unpack .../6-openjdk-8-jre_8u191-b12-2ubuntu0.18.04.1_amd64.deb ...
# Unpacking openjdk-8-jre:amd64 (8u191-b12-2ubuntu0.18.04.1) ...
# Selecting previously unselected package openjdk-8-jdk:amd64.
# Preparing to unpack .../7-openjdk-8-jdk_8u191-b12-2ubuntu0.18.04.1_amd64.deb ...
# Unpacking openjdk-8-jdk:amd64 (8u191-b12-2ubuntu0.18.04.1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Setting up fonts-dejavu-core (2.37-1) ...
# Setting up libxxf86dga1:amd64 (2:1.1.4-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Setting up fonts-dejavu-extra (2.37-1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# Setting up x11-utils (7.7+3build1) ...
# Setting up libatk-wrapper-java (0.33.3-20ubuntu0.1) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.33.3-20ubuntu0.1) ...
# Setting up openjdk-8-jre:amd64 (8u191-b12-2ubuntu0.18.04.1) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/policytool to provide /usr/bin/policytool (policytool) in auto mode
# Setting up openjdk-8-jdk:amd64 (8u191-b12-2ubuntu0.18.04.1) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/appletviewer to provide /usr/bin/appletviewer (appletviewer) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/jconsole to provide /usr/bin/jconsole (jconsole) in auto mode
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Collecting JPype1-py3
#   Downloading https://files.pythonhosted.org/packages/59/90/149647ac2c8649a5983fcc47c78f2881af80cbd99f54248ac31b3d611618/JPype1-py3-0.5.5.2.tar.gz (87kB)
#     100% |████████████████████████████████| 92kB 3.3MB/s
# Building wheels for collected packages: JPype1-py3
#   Building wheel for JPype1-py3 (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/76/7d/41/829109c81b0c4bdca8047fb9e0a573d4db3b671fbbe84a84f3
# Successfully built JPype1-py3
# Installing collected packages: JPype1-py3
# Successfully installed JPype1-py3-0.5.5.2
# Collecting konlpy
#   Downloading https://files.pythonhosted.org/packages/e5/3d/4e983cd98d87b50b2ab0387d73fa946f745aa8164e8888a714d5129f9765/konlpy-0.5.1-py2.py3-none-any.whl (19.4MB)
#     100% |████████████████████████████████| 19.4MB 2.1MB/s
# Collecting JPype1>=0.5.7 (from konlpy)
#   Downloading https://files.pythonhosted.org/packages/c4/4b/60a3e63d51714d4d7ef1b1efdf84315d118a0a80a5b085bb52a7e2428cdc/JPype1-0.6.3.tar.gz (168kB)
#     100% |████████████████████████████████| 174kB 30.9MB/s
# Building wheels for collected packages: JPype1
#   Building wheel for JPype1 (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/0e/2b/e8/c0b818ac4b3d35104d35e48cdc7afe27fc06ea277feed2831a
# Successfully built JPype1
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-0.6.3 konlpy-0.5.1

# %%
import tensorflow as tf
import model as ml
import data
import numpy as np
import os
import sys

from configs import DEFINES

# %% [markdown]
# # 사전 만들기

# %%
# !rm -rf ../data_in
# !mkdir ../data_in
# !wget https://raw.githubusercontent.com/sjs2109/tensorflow-ml-nlp/master/6.CHATBOT/data_in/ChatBotData.csv -P ../data_in
# Out:
# --2019-03-27 01:28:05--  https://raw.githubusercontent.com/sjs2109/tensorflow-ml-nlp/master/6.CHATBOT/data_in/ChatBotData.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 889842 (869K) [text/plain]
# Saving to: ‘../data_in/ChatBotData.csv’
#
# ChatBotData.csv     100%[===================>] 868.99K  --.-KB/s    in 0.07s
#
# 2019-03-27 01:28:05 (11.3 MB/s) - ‘../data_in/ChatBotData.csv’ saved [889842/889842]

# %%
tf.app.flags.DEFINE_string('f', '', 'kernel')
DEFINES.batch_size
# Out:
# 64

# %%
DATA_OUT_PATH = './data_out/'
data_out_path = os.path.join(os.getcwd(), DATA_OUT_PATH)
os.makedirs(data_out_path, exist_ok=True)
# 데이터를 통한 사전 구성 한다.
char2idx, idx2char, vocabulary_length = data.load_vocabulary()
# 훈련 데이터와 테스트 데이터를 가져온다.
train_input, train_label, eval_input, eval_label = data.load_data()

# %% [markdown]
# # 데이터 만들기

# %%
char2idx
# Out:
# {'<PAD>': 0,
#  '<SOS>': 1,
#  '<END>': 2,
#  '<UNK>': 3,
#  '할수있습니다': 4,
#  '베프가': 5,
#  '차분하게': 6,
#  '잔소리해': 7,
#  '서글퍼': 8,
#  '따뜻': 9,
#  '보자': 10,
#  '부르려고': 11,
#  '대상': 12,
#  '알면서도': 13,
#  '설명': 14,
#  '번호키': 15,
#  '개강총회인데': 16,
#  '그치는': 17,
#  '그런일은': 18,
#  '알았나봐': 19,
#  '추억은': 20,
#  '등산해요': 21,
#  '꽃도': 22,
#  '아파할': 23,
#  '시골에서': 24,
#  '단한번도': 25,
#  '캬': 26,
#  '의자가': 27,
#  '될라나': 28,
#  '잘가': 29,
#  '짠한건': 30,
#  '집나갈까': 31,
#  '안올텐데': 32,
#  '이기적이어도': 33,
#  '아프지': 34,
#  '흔하지': 35,
#  '오기': 36,
#  '문화센터라도': 37,
#  '기억하고싶은것만': 38,
#  '오려나요': 39,
#  '하긴': 40,
#  '해로워요': 41,
#  '밤늦게': 42,
#  '슬픔이': 43,
#  '화장하는': 44,
#  '맞는데': 45,
#  '거겠죠': 46,
#  '면접만': 47,
#  '악몽이네': 48,
#  '싸울까': 49,
#  '휴반년이라는': 50,
#  '놀까요': 51,
#  '장벽을': 52,
#  '있다니': 53,
#  '은행': 54,
#  '짝남에게': 55,
#  '사춘기인가봅니다': 56,
#  '행복해보이나': 57,
#  '대기업에': 58,
#  '조심조심': 59,
#  '심해져': 60,
#  '일정이': 61,
#  '가질': 62,
#  '사랑인가': 63,
#  '이기는': 64,
#  '스킨십하려고해': 65,
#  '진심으로': 66,
#  '알았어': 67,
#  '학식': 68,
#  '기운내는': 69,
#  '붙잡아보려': 70,
#  '내려가서': 71,
#  '어둠에서': 72,
#  '고민만': 73,
#  '이것': 74,
#  '친구인척': 75,
#  '짝남이든': 76,
#  '선생님이요': 77,
#  '이별한지': 78,
#  '기로에': 79,
#  '체조를': 80,
#  '0이야': 81,
#  '웃기지마': 82,
#  '여지준': 83,
#  '고와야': 84,
#  '소리를': 85,
#  '연예인과': 86,
#  '들음': 87,
#  '선택권이': 88,
#  '기간인데': 89,
#  '신겨': 90,
#  '되고싶어': 91,
#  '화났었지만': 92,
#  '차단해야만': 93,
#  '재회는': 94,
#  '싫대': 95,
#  '안되있을까': 96,
#  '이별에는': 97,
#  '달리고': 98,
#  '소중한': 99,
#  '전공에': 100,
#  '달에는': 101,
#  '것보다': 102,
#  '소중합니다': 103,
#  '지하철에서': 104,
#  '오니울컥하네': 105,
#  '목록에서': 106,
#  '나아질거예요': 107,
#  '없으면서': 108,
#  '싱숭생숭했겠네요': 109,
#  '어이없어': 110,
#  '선택했어요': 111,
#  '고시생이면': 112,
#  '주변의': 113,
#  '오니': 114,
#  '천근만근이다': 115,
#  '먼데': 116,
#  '차이는': 117,
#  '잊어버려요': 118,
#  '눌러': 119,
#  '고쳐봐도': 120,
#  '유행하고있어요': 121,
#  '금연': 122,
#  '부담스러운지': 123,
#  '변기': 124,
#  '마지막이겠죠': 125,
#  '알아요': 126,
#  '경과보고서': 127,
#  '하지요': 128,
#  '자금도': 129,
#  '수면': 130,
#  '얻으려면': 131,
#  '하늘만큼': 132,
#  '비슷한': 133,
#  '붙여놓은': 134,
#  '코': 135,
#  '않은건': 136,
#  '만나야할까': 137,
#  '알려줘요': 138,
#  '방법이겠죠': 139,
#  '사랑인지': 140,
#  '6년이란': 141,
#  '영장': 142,
#  '재회했다가': 143,
#  '마시는': 144,
#  '꽃을': 145,
#  '곧1년': 146,
#  '인기': 147,
#  '실패할': 148,
#  '신뢰가': 149,
#  '어찌됐던': 150,
#  '부담스러움': 151,
#  '쉬운데': 152,
#  '매세요': 153,
#  '먹는걸': 154,
#  '알려고': 155,
#  '다시돌아': 156,
#  '어느날': 157,
#  '들었어요': 158,
#  '바꿀': 159,
#  '설마했던': 160,
#  '능력치': 161,
#  '나이가': 162,
#  '절대불공평': 163,
#  'sns에': 164,
#  '아이구': 165,
#  '않아질': 166,
#  '알아버렸네': 167,
#  '대출': 168,
#  '목걸이': 169,
#  '날씨': 170,
#  '장마인데': 171,
#  '싸움을': 172,
#  '다같이': 173,
#  '특판': 174,
#  '속에': 175,
#  '나아지길': 176,
#  '감당이': 177,
#  '그럴게요': 178,
#  '변명의': 179,
#  '어쩔수없이': 180,
#  '발표는': 181,
#  '되돌아보세요': 182,
#  '저좀': 183,
#  '가운데': 184,
#  '면도해야': 185,
#  '감기인거': 186,
#  '이루어졌으면': 187,
#  '염색이나': 188,
#  '문제이기도': 189,
#  '피우는': 190,
#  '존댓말': 191,
#  '생활용품이': 192,
#  '학교갈': 193,
#  '모든걸': 194,
#  '매너인지': 195,
#  '사랑하다고': 196,
#  '재회하는': 197,
#  '치맥이죠': 198,
#  '포근포근': 199,
#  '흘렀는데도': 200,
#  '대하는게': 201,
#  '당했던건가': 202,
#  '성별이': 203,
#  '초라해지는': 204,
#  '가자던': 205,
#  '카톡이': 206,
#  '이별해야': 207,
#  '방정이야': 208,
#  '지긋지긋한': 209,
#  '안타까운': 210,
#  '못내는': 211,
#  '호구로': 212,
#  '생기지': 213,
#  '믿었습니다': 214,
#  '휴식도': 215,
#  '사랑만으로': 216,
#  '쉽습니다': 217,
#  '사랑했나봐요': 218,
#  '미세먼지': 219,
#  '사랑한다고': 220,
#  '헐었어': 221,
#  '미치겠는데': 222,
#  '걸을수': 223,
#  '두달째': 224,
#  '고백이': 225,
#  '말하고': 226,
#  '세우고': 227,
#  '말해야죠': 228,
#  '만났는데': 229,
#  '꿈도': 230,
#  '푹': 231,
#  '단발': 232,
#  '쏟아진다': 233,
#  '전학': 234,
#  '노래야': 235,
#  '올지도': 236,
#  '상담을': 237,
#  '심장이': 238,
#  '만족할': 239,
#  '5년만난': 240,
#  '느낌이길': 241,
#  '고집하고는': 242,
#  '선생님한테': 243,
#  '눈물만': 244,
#  '잘해줘서요': 245,
#  '쇼핑하고': 246,
#  '짐을': 247,
#  '헤어졌어': 248,
#  '자세히': 249,
#  '연락했으면': 250,
#  '의미가': 251,
#  '맘에': 252,
#  '절친': 253,
#  '시절엔': 254,
#  '성공할거예요': 255,
#  '안타까워': 256,
#  '대해요': 257,
#  '차단시': 258,
#  '오래된': 259,
#  '끝까지': 260,
#  '안해도': 261,
#  '그것만큼': 262,
#  '아니지만': 263,
#  '카드가': 264,
#  '이런생각이': 265,
#  '담은': 266,
#  '해보고': 267,
#  '기회는': 268,
#  '사업하기': 269,
#  '베트남어': 270,
#  '욕먹었어': 271,
#  '이성이니까': 272,
#  '벋어나는': 273,
#  '문열다': 274,
#  '충전기': 275,
#  '말이네요': 276,
#  '후련하다니': 277,
#  '좋은가요': 278,
#  '변화하는': 279,
#  '귀찮게': 280,
#  '학점': 281,
#  '쳐': 282,
#  '여쭈어볼것이있습니다': 283,
#  '붙잡으세요': 284,
#  '습관': 285,
#  '일하면서': 286,
#  '최고다': 287,
#  '연인을': 288,
#  '추워져서인지': 289,
#  '잊고싶어도': 290,
#  '선생님께': 291,
#  '냉정한데': 292,
#  '맞는지': 293,
#  '맛있죠': 294,
#  '헛헛하군요': 295,
#  '구상': 296,
#  '크게': 297,
#  '대부분': 298,
#  '행복은': 299,
#  '중한지': 300,
#  '웃거나': 301,
#  '헤어짐의': 302,
#  '관심있고': 303,
#  '정장': 304,
#  '상담좀해주세': 305,
#  '숨막히네': 306,
#  '일기를': 307,
#  '심각해요': 308,
#  '알아주는': 309,
#  '티가': 310,
#  '띠동갑': 311,
#  '지지가': 312,
#  '놔둬야하는데': 313,
#  '살아요': 314,
#  '기분이가': 315,
#  '쑥쑥': 316,
#  '끌어올려보세요': 317,
#  '다니거나': 318,
#  '있었지하고': 319,
#  '전하지': 320,
#  '덜할텐데': 321,
#  '아스피린': 322,
#  '피나는': 323,
#  '시험을': 324,
#  '술마시러가는게': 325,
#  '연락해보는게': 326,
#  '꿈같은': 327,
#  '미련이겠죠': 328,
#  '수상한': 329,
#  '심한': 330,
#  '상태일': 331,
#  '연금': 332,
#  '김치도': 333,
#  '피시방데이트도하고싶은데': 334,
#  '맞춰주고': 335,
#  '알아내': 336,
#  '쓰레기기는': 337,
#  '베트남': 338,
#  '걸게': 339,
#  '읽어': 340,
#  '모르고': 341,
#  '뭐할': 342,
#  '힘들까': 343,
#  '나가볼까': 344,
#  '시작을': 345,
#  '욕을해도': 346,
#  '왜이러니': 347,
#  '해야할듯': 348,
#  '만들어보려해': 349,
#  '실험실': 350,
#  '예쁜데': 351,
#  '초초하다': 352,
#  '납니다': 353,
#  '들켜서': 354,
#  '운동하면서': 355,
#  '구멍': 356,
#  '보낼까': 357,
#  '다시는': 358,
#  '주말부터': 359,
#  '엊그제': 360,
#  '의자': 361,
#  '근교': 362,
#  '바지': 363,
#  '바람나서': 364,
#  '들어도': 365,
#  '것부터': 366,
#  '받으셨나': 367,
#  '분끼리': 368,
#  '정리하길': 369,
#  '떠나보는': 370,
#  '떠나갔네': 371,
#  '술자리에서': 372,
#  '대충한': 373,
#  '통해서': 374,
#  '차이다가': 375,
#  '마음과': 376,
#  '흘렀습니다': 377,
#  '입나': 378,
#  '좋아졌나봅니다': 379,
#  '근질근질': 380,
#  '썼어': 381,
#  '힘내봐요': 382,
#  '밥': 383,
#  '여사친': 384,
#  '문제는': 385,
#  '해주고': 386,
#  '연인도': 387,
#  '사회생활로': 388,
#  '버릴수록': 389,
#  '고통이': 390,
#  '이것저것': 391,
#  '독학하려니까': 392,
#  '사랑없이': 393,
#  '마셔야겠다': 394,
#  '얘': 395,
#  '위축된': 396,
#  '깨질까': 397,
#  '시작이죠': 398,
#  '그리운가봐요': 399,
#  '말이라도': 400,
#  '떠납니다': 401,
#  '색다른': 402,
#  '탈모왔나봐': 403,
#  '떨궜어': 404,
#  '걸은': 405,
#  '긁었어': 406,
#  '땡기네': 407,
#  '6일간의': 408,
#  '맞는거임': 409,
#  '불렀는데': 410,
#  '가려질까': 411,
#  '치료한다': 412,
#  '못하겠음': 413,
#  '행복해': 414,
#  '찍어': 415,
#  '사랑했다는': 416,
#  '다녀와': 417,
#  '미련만': 418,
#  '편지도': 419,
#  '막막하겠네요': 420,
#  '나이죠': 421,
#  '잠기는': 422,
#  '우세요': 423,
#  '선택해보세요': 424,
#  '열어버렸네': 425,
#  '기다리는': 426,
#  '꺼내기가': 427,
#  '의심하지': 428,
#  '끝인가': 429,
#  '사용해보세요': 430,
#  '추천해들요': 431,
#  '설레는게': 432,
#  '편안하게': 433,
#  '전남자친구보다': 434,
#  '억지로': 435,
#  '전': 436,
#  '기억만': 437,
#  '힘든': 438,
#  '이별일까': 439,
#  '입을': 440,
#  '운동하다': 441,
#  '통장을': 442,
#  '유지하는': 443,
#  '먹어야지': 444,
#  '첫인상': 445,
#  '없은': 446,
#  '맞춰주세요': 447,
#  '알아차렸을': 448,
#  '보수적이어도': 449,
#  '부담스럽다면': 450,
#  '구남친이랑': 451,
#  '알아보셔요': 452,
#  '인지시켜야죠': 453,
#  '써봅니다': 454,
#  '친해졌나봐요': 455,
#  '졸려': 456,
#  '면도하는': 457,
#  '뜨끈한': 458,
#  '대리효도시키는': 459,
#  '놀랐나봐요': 460,
#  '거기까지였나봐요': 461,
#  '익숙함이라는': 462,
#  '있었으니까요': 463,
#  '불안해요': 464,
#  '부담돼': 465,
#  '눈에서': 466,
#  '심증은': 467,
#  '미루는': 468,
#  '개가': 469,
#  '받음': 470,
#  '무리가': 471,
#  '길기만': 472,
#  '샤워를': 473,
#  '욕해': 474,
#  '궁금할만': 475,
#  '때를': 476,
#  '비가오면': 477,
#  '어렵네요': 478,
#  '이겨내기': 479,
#  '가망': 480,
#  '잊어요': 481,
#  '편으로': 482,
#  '왔나봐': 483,
#  '이직을': 484,
#  '나눠있지': 485,
#  '끊으세요': 486,
#  '순간에는': 487,
#  '생각되면': 488,
#  '떨어져서': 489,
#  '지쳐도': 490,
#  '원츄': 491,
#  '주차할데': 492,
#  '보고싶은데': 493,
#  '먹은거': 494,
#  '화나면': 495,
#  '비가오네': 496,
#  '해보는건': 497,
#  '커피도': 498,
#  '조급해하지': 499,
#  '맞은': 500,
#  '행적': 501,
#  '지워버리자': 502,
#  '끝의': 503,
#  '단계라면': 504,
#  '면도기랑': 505,
#  '전문가를': 506,
#  '오늘도': 507,
#  '찾으실': 508,
#  '떨리더라': 509,
#  '하라고': 510,
#  '헤어져야할': 511,
#  '맘도': 512,
#  '바뀌고': 513,
#  '매력이겠죠': 514,
#  '다가와': 515,
#  '썸이지': 516,
#  '힘듬': 517,
#  '베풀되': 518,
#  '귀찮다': 519,
#  '가족들이랑': 520,
#  '시련': 521,
#  '부터': 522,
#  '익숙해져서': 523,
#  '얼마전': 524,
#  '좋아서': 525,
#  '5월의': 526,
#  '해결해야할까': 527,
#  '사랑과': 528,
#  '봄방학이다': 529,
#  '처음부터': 530,
#  '싫어해': 531,
#  '괴롭혀': 532,
#  '잔고가': 533,
#  '공시생이면': 534,
#  '수신차단의': 535,
#  '그쪽': 536,
#  '아울렛': 537,
#  '설명이': 538,
#  '용기내세요': 539,
#  '작아지나봐요': 540,
#  '뒤돌아봐도': 541,
#  '사람그리고': 542,
#  '판단력을': 543,
#  '오해가': 544,
#  '깨다': 545,
#  '무리하지': 546,
#  '영원한': 547,
#  '되었네요': 548,
#  '…': 549,
#  '게임하다': 550,
#  '먹으면': 551,
#  '배고프면': 552,
#  '떠난다는': 553,
#  '비교돼': 554,
#  '기원합니다': 555,
#  '철': 556,
#  '사랑도': 557,
#  '첫눈': 558,
#  '아오': 559,
#  '액션은': 560,
#  '소식에': 561,
#  '필요했을': 562,
#  '월요일보단': 563,
#  '속아주는': 564,
#  '길다면': 565,
#  '에이씨': 566,
#  '초라하게': 567,
#  '진짜미칠꺼같네': 568,
#  '탈퇴합니다': 569,
#  '사귀기': 570,
#  '잡힐듯하면서': 571,
#  '행복하지만은': 572,
#  '하면': 573,
#  '그만두세요': 574,
#  '만남보다긴이별': 575,
#  '들으면서': 576,
#  '말았으면': 577,
#  '마지막': 578,
#  '사춘기로부터의': 579,
#  '걸음이어도': 580,
#  '한숨만': 581,
#  '잊어가는': 582,
#  '추천하고': 583,
#  '지켜': 584,
#  '글이': 585,
#  '결정이었나봐요': 586,
#  '잡념이': 587,
#  '신입이': 588,
#  '부모님만의': 589,
#  '쇼핑했더니': 590,
#  '가능하면': 591,
#  '사랑이라는': 592,
#  '아닐거예요': 593,
#  '너를': 594,
#  '부딪히면': 595,
#  '힘이': 596,
#  '안돌아오나': 597,
#  '조심': 598,
#  '나약하지': 599,
#  '뭐있나': 600,
#  '하려다': 601,
#  '그후': 602,
#  '소원을': 603,
#  '나': 604,
#  '오빠': 605,
#  '마주쳐': 606,
#  '향이': 607,
#  '흔들리네': 608,
#  '무기력한': 609,
#  '소모': 610,
#  '찌는': 611,
#  '뚱뚱한데': 612,
#  '묻어두는게': 613,
#  '깊어지지': 614,
#  '예뻐보이는': 615,
#  '등을': 616,
#  '두분이': 617,
#  '가득한가봐요': 618,
#  '후회없게': 619,
#  '알겠어서': 620,
#  '애매하네요': 621,
#  '한데': 622,
#  '후폭풍은': 623,
#  '버텼어요': 624,
#  '튀어': 625,
#  '느끼지': 626,
#  '하루이길': 627,
#  '못해봤던': 628,
#  '초록초록하네요': 629,
#  '가져가세요': 630,
#  '확인': 631,
#  '발을': 632,
#  '공원이나': 633,
#  '회사가는': 634,
#  '다녀온': 635,
#  '그녀가': 636,
#  '배신감': 637,
#  '무시하세요': 638,
#  '지갑': 639,
#  '결혼해서도': 640,
#  '좋아하는게': 641,
#  '고르고': 642,
#  '츤데레': 643,
#  '줄을': 644,
#  '생일입니다': 645,
#  '에혀': 646,
#  '안와여': 647,
#  '싶은대로': 648,
#  '6살': 649,
#  '뻔뻔해': 650,
#  '헤어졌는데만나자는건': 651,
#  '친해서': 652,
#  '쪼잔하네요': 653,
#  '떨리네요': 654,
#  '끝냅니다': 655,
#  '돌직구를': 656,
#  '개당황했잖아': 657,
#  '또났어': 658,
#  '사연이': 659,
#  '의외야': 660,
#  '피는': 661,
#  '능력이겠죠': 662,
#  '이브네': 663,
#  '견디기가': 664,
#  '연락한다': 665,
#  '철벽이야': 666,
#  '좋아하길': 667,
#  '서운하다고': 668,
#  '적극적으로': 669,
#  '염탐하고': 670,
#  '발라드': 671,
#  '고기앞이죠': 672,
#  '문이': 673,
#  '총회에': 674,
#  '행복해질까': 675,
#  '오래걸려': 676,
#  '7개월': 677,
#  '꽝이야': 678,
#  '감히': 679,
#  '술취해서': 680,
#  '바라게': 681,
#  '바라요': 682,
#  '갔다왔는데': 683,
#  '프로포즈': 684,
#  '남을까요': 685,
#  '의심': 686,
#  '찬물만': 687,
#  '이뤄지지': 688,
#  '친구들과': 689,
#  '이번달': 690,
#  '접어두세요': 691,
#  '보증금': 692,
#  '가입': 693,
#  '중2': 694,
#  '전화왔어': 695,
#  '잘못된건': 696,
#  '행복하기': 697,
#  '평화가': 698,
#  '문제겠네요': 699,
#  '찜질방가서': 700,
#  '일어나': 701,
#  '잘들': 702,
#  '전부였던': 703,
#  '아닌걸': 704,
#  '첫사랑이야': 705,
#  '선이': 706,
#  '교직이수': 707,
#  '함께하고': 708,
#  '정리가될것같아': 709,
#  '기본으로': 710,
#  '신상으로': 711,
#  '재활용도': 712,
#  '헤어졋네': 713,
#  '이쁘고': 714,
#  '바랄게요': 715,
#  '새는': 716,
#  '온다면': 717,
#  '잘해주는지': 718,
#  '다가왔습니다': 719,
#  '언제든': 720,
#  '그쪽은': 721,
#  '자신으로': 722,
#  '번하니': 723,
#  '대체왜': 724,
#  '근사한': 725,
#  '전했네': 726,
#  '시기를': 727,
#  '찾은게': 728,
#  '잊었다면': 729,
#  '번씩': 730,
#  '받은지': 731,
#  '따지지': 732,
#  '4년을': 733,
#  '눈물로': 734,
#  '다썸이': 735,
#  '연락': 736,
#  '아들': 737,
#  '즐겨야지': 738,
#  '디져트': 739,
#  '침묵하세요': 740,
#  '몇일째': 741,
#  '꿨는지': 742,
#  '마음이죠': 743,
#  '판정': 744,
#  '사랑해요': 745,
#  '느껴지겠어요': 746,
#  '편이에요': 747,
#  '말고도': 748,
#  '되지만': 749,
#  '보지': 750,
#  '사귀어도': 751,
#  '무너져요': 752,
#  '살아야': 753,
#  '되어버렸습니다': 754,
#  '괜찮아진': 755,
#  '초대하려고': 756,
#  '뭐예요': 757,
#  '단순하다': 758,
#  '없어ㅋㅋ': 759,
#  '우스워질거': 760,
#  '늙어간다': 761,
#  '지내자': 762,
#  '박도': 763,
#  '바쁘면': 764,
#  '괴로워요': 765,
#  '못하니': 766,
#  '지속해도': 767,
#  '날고': 768,
#  '결정하는게': 769,
#  '많아졌으면': 770,
#  '회사는': 771,
#  '소개': 772,
#  '마음': 773,
#  '됐어요': 774,
#  '피해만': 775,
#  '성공에서': 776,
#  '높겠네요': 777,
#  '단계니': 778,
#  '계절이': 779,
#  '학생이야': 780,
#  '식욕폭발해서': 781,
#  '둘다': 782,
#  '드려요': 783,
#  '슬쩍': 784,
#  '환심': 785,
#  '무뎌져가나봐': 786,
#  '오늘부터': 787,
#  '허한가봅니다': 788,
#  '맘편할': 789,
#  '행동이에요': 790,
#  '재밌어': 791,
#  '아프니까': 792,
#  '좋아하는': 793,
#  '맞춰지네': 794,
#  '질리지': 795,
#  '꼼꼼한데': 796,
#  '바늘': 797,
#  '믿고': 798,
#  '맡겨보세요': 799,
#  '소식이었으면': 800,
#  '싫은': 801,
#  '운동하자는데': 802,
#  '술마시면': 803,
#  '힘들어졌어요': 804,
#  '후각이': 805,
#  '자리에서': 806,
#  '질투난다고': 807,
#  '저한테도': 808,
#  '흐르는게': 809,
#  '화': 810,
#  '데': 811,
#  '간절히': 812,
#  '물어도': 813,
#  '교회': 814,
#  '내자신': 815,
#  '하니까': 816,
#  '헤어졌을때': 817,
#  '눈물과': 818,
#  '사랑받는': 819,
#  '건강은': 820,
#  '보신': 821,
#  '멋을': 822,
#  '신경쓰여': 823,
#  '부족한': 824,
#  '순수했던': 825,
#  '하지말고': 826,
#  '트라우마가': 827,
#  '건강이': 828,
#  '나와': 829,
#  '놔버린': 830,
#  '오는날': 831,
#  '깊어져': 832,
#  '그분과의': 833,
#  '여전히': 834,
#  '12일째': 835,
#  '전해졌으면': 836,
#  '시켜줬어': 837,
#  '텅비고': 838,
#  '엉망이지': 839,
#  '잔인하네': 840,
#  '너무도': 841,
#  '오는지': 842,
#  '구하는': 843,
#  '자소설': 844,
#  '5년간': 845,
#  '사랑에는': 846,
#  '이뤄진': 847,
#  '문질러': 848,
#  '인기있는': 849,
#  '생겨서': 850,
#  '확신하는': 851,
#  '기다리던': 852,
#  '중소기업이라도': 853,
#  '보다': 854,
#  '관심있나': 855,
#  '자격증': 856,
#  '옷을': 857,
#  '카톡하는데': 858,
#  '휴련하네': 859,
#  '풀리지도': 860,
#  '사귀어서': 861,
#  '왔나봐요': 862,
#  '고시원': 863,
#  '차있더라': 864,
#  '미친것같아': 865,
#  '쓰세요': 866,
#  '받아들여야지': 867,
#  '들지만': 868,
#  '명언이네요': 869,
#  '해치지': 870,
#  '이어질': 871,
#  '생리현상은': 872,
#  '낮잠은': 873,
#  '난폭한게': 874,
#  '했었으니까요': 875,
#  '학생만': 876,
#  '않을까봐': 877,
#  '도구죠': 878,
#  '나와준': 879,
#  '고무신': 880,
#  '안줘': 881,
#  '오래되었는데': 882,
#  '어떤거를': 883,
#  '기다리는게': 884,
#  '잤나봐': 885,
#  '버텨내고': 886,
#  '막을': 887,
#  '3개월전에': 888,
#  '받는거': 889,
#  '않겠지': 890,
#  '만나자면': 891,
#  '예쁠': 892,
#  '좋아해주세요': 893,
#  '잊어버리는': 894,
#  '떨어': 895,
#  '그리울': 896,
#  '느껴지나요': 897,
#  '나오겠지': 898,
#  '상처받기': 899,
#  '다름': 900,
#  '반복되면': 901,
#  '거야-어린왕자': 902,
#  '헤어짐에도': 903,
#  '좋아하지만': 904,
#  '충전하세요': 905,
#  '준비하지': 906,
#  '이유는': 907,
#  '중요한': 908,
#  '행사니까요': 909,
#  '기다려야': 910,
#  '좋아하다니': 911,
#  '중요하겠지': 912,
#  '낀게': 913,
#  '차였는데': 914,
#  '가득한': 915,
#  '괴로운': 916,
#  '종합해': 917,
#  '공공장소에서의': 918,
#  '짝사랑하게': 919,
#  '그립겠어요': 920,
#  '시간이었던': 921,
#  '이별여행이라도': 922,
#  '마실만한': 923,
#  '정신없이': 924,
#  '사람일지도': 925,
#  '1달째': 926,
#  '그를': 927,
#  '짝남이었나봐': 928,
#  '결혼날짜': 929,
#  '이겨내고': 930,
#  '1년도': 931,
#  '열흘이란': 932,
#  '좋을거': 933,
#  '주인공이에요': 934,
#  '견디고있었는데': 935,
#  '발전적인': 936,
#  '가능하겟죠': 937,
#  '스타일이야': 938,
#  '태어': 939,
#  '정열적으로': 940,
#  '처음은': 941,
#  '끌지': 942,
#  '아픔': 943,
#  '휨': 944,
#  '무색하다': 945,
#  '별의별': 946,
#  '부담된다면': 947,
#  '햇갈리게': 948,
#  '비참한': 949,
#  '안했다': 950,
#  '갱년긴가': 951,
#  '우울한': 952,
#  '다가갈': 953,
#  '정답이': 954,
#  '들여다보세요': 955,
#  '돌아올': 956,
#  '자기관리가': 957,
#  '집착하지마세요': 958,
#  '팔뚝': 959,
#  '나온다면': 960,
#  '나름이래요': 961,
#  '찝적대는': 962,
#  '해볼까': 963,
#  '일들이요': 964,
#  '생일인데': 965,
#  '부부싸움은': 966,
#  '가치가': 967,
#  '4일': 968,
#  '쉬었다': 969,
#  '아이를': 970,
#  '코인노래방': 971,
#  '우울해요': 972,
#  '없다': 973,
#  '싶습니다': 974,
#  '그런건가봐요': 975,
#  '빨렸어': 976,
#  '성장통이': 977,
#  '만나도': 978,
#  '터닝포인트가': 979,
#  '스드메': 980,
#  '그가': 981,
#  '재미있을': 982,
#  '기본적인': 983,
#  '힘들까요': 984,
#  '타긴': 985,
#  '브랜드있어': 986,
#  '점심시간잠깐': 987,
#  '쳐다봐': 988,
#  '단': 989,
#  '약이긴': 990,
#  '아닌가봐': 991,
#  '확실하겠죠': 992,
#  '짝사랑하는데': 993,
#  '끝나': 994,
#  '쇼핑': 995,
#  '얼마든지': 996,
#  '맞길': 997,
#  '무슨마음일까': 998,
#  '잠길': 999,
#  ...}

# %%
char2idx, idx2char, vocabulary_length = data.load_vocabulary()
# 훈련 데이터와 테스트 데이터를 가져온다.
train_input, train_label, eval_input, eval_label = data.load_data()

# 훈련셋 인코딩 만드는 부분이다.
train_input_enc, train_input_enc_length = data.enc_processing(train_input, char2idx)
# 훈련셋 디코딩 입력 부분 만드는 부분이다.
train_output_dec, train_output_dec_length = data.dec_output_processing(train_label, char2idx)
# 훈련셋 디코딩 출력 부분 만드는 부분이다.
train_target_dec = data.dec_target_processing(train_label, char2idx)

# 평가셋 인코딩 만드는 부분이다.
eval_input_enc, eval_input_enc_length = data.enc_processing(eval_input, char2idx)
# 평가셋 인코딩 만드는 부분이다.
eval_output_dec, eval_output_dec_length = data.dec_output_processing(eval_label, char2idx)
# 평가셋 인코딩 만드는 부분이다.
eval_target_dec = data.dec_target_processing(eval_label, char2idx)

# %% [markdown]
# # 체크 포인트 경로 만들기

# %%
# 현재 경로'./'에 현재 경로 하부에 
# 체크 포인트를 저장한 디렉토리를 설정한다.
check_point_path = os.path.join(os.getcwd(), DEFINES.check_point_path)
# 디렉토리를 만드는 함수이며 두번째 인자 exist_ok가 
# True이면 디렉토리가 이미 존재해도 OSError가 
# 발생하지 않는다.
# exist_ok가 False이면 이미 존재하면 
# OSError가 발생한다.
os.makedirs(check_point_path, exist_ok=True)

# %% [markdown]
# # 에스티 메이터 구성

# %%
 # 에스티메이터 구성한다.
    classifier = tf.estimator.Estimator(
        model_fn=ml.Model,  # 모델 등록한다.
        model_dir=DEFINES.check_point_path,  # 체크포인트 위치 등록한다.
        params={  # 모델 쪽으로 파라메터 전달한다.
            'embedding_size': DEFINES.embedding_size,
            'model_hidden_size': DEFINES.model_hidden_size,  # 가중치 크기 설정한다.
            'ffn_hidden_size': DEFINES.ffn_hidden_size,
            'attention_head_size': DEFINES.attention_head_size,
            'learning_rate': DEFINES.learning_rate,  # 학습율 설정한다.
            'vocabulary_length': vocabulary_length,  # 딕셔너리 크기를 설정한다.
            'embedding_size': DEFINES.embedding_size,  # 임베딩 크기를 설정한다.
            'layer_size': DEFINES.layer_size,
            'max_sequence_length': DEFINES.max_sequence_length,
            'xavier_initializer': DEFINES.xavier_initializer
        })
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': './data_out/check_point', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fbfff998b70>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %% [markdown]
# # 학습 실행

# %%
 classifier.train(input_fn=lambda: data.train_input_fn(
        train_input_enc, train_output_dec, train_target_dec, DEFINES.batch_size), steps=DEFINES.train_steps)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/metrics_impl.py:455: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./data_out/check_point/model.ckpt.
# INFO:tensorflow:loss = 9.768401, step = 0
# INFO:tensorflow:global_step/sec: 11.7224
# INFO:tensorflow:loss = 1.3843961, step = 100 (8.537 sec)
# INFO:tensorflow:global_step/sec: 14.2311
# INFO:tensorflow:loss = 1.121856, step = 200 (7.027 sec)
# INFO:tensorflow:global_step/sec: 14.2149
# INFO:tensorflow:loss = 1.1351421, step = 300 (7.031 sec)
# INFO:tensorflow:global_step/sec: 14.2297
# INFO:tensorflow:loss = 1.1516763, step = 400 (7.027 sec)
# INFO:tensorflow:global_step/sec: 14.3002
# INFO:tensorflow:loss = 1.0783396, step = 500 (6.998 sec)
# INFO:tensorflow:global_step/sec: 14.4298
# INFO:tensorflow:loss = 0.99477583, step = 600 (6.928 sec)
# INFO:tensorflow:global_step/sec: 14.2701
# INFO:tensorflow:loss = 1.0112907, step = 700 (7.010 sec)
# INFO:tensorflow:global_step/sec: 14.2878
# INFO:tensorflow:loss = 0.0011496764, step = 18700 (6.936 sec)
# INFO:tensorflow:global_step/sec: 14.3981
# INFO:tensorflow:loss = 0.0008676091, step = 18800 (6.947 sec)
# INFO:tensorflow:global_step/sec: 14.3286
# INFO:tensorflow:loss = 0.0008615309, step = 18900 (6.978 sec)
# INFO:tensorflow:global_step/sec: 14.3462
# INFO:tensorflow:loss = 0.00026060664, step = 19000 (6.974 sec)
# INFO:tensorflow:global_step/sec: 14.3882
# INFO:tensorflow:loss = 0.0007013259, step = 19100 (6.947 sec)
# INFO:tensorflow:global_step/sec: 14.3541
# INFO:tensorflow:loss = 4.2711017e-05, step = 19200 (6.964 sec)
# INFO:tensorflow:global_step/sec: 14.3531
# INFO:tensorflow:loss = 0.00014902554, step = 19300 (6.970 sec)
# INFO:tensorflow:global_step/sec: 14.3129
# INFO:tensorflow:loss = 0.0036281035, step = 19400 (6.985 sec)
# INFO:tensorflow:global_step/sec: 14.4019
# INFO:tensorflow:loss = 0.0010449627, step = 19500 (6.955 sec)
# INFO:tensorflow:global_step/sec: 14.3158
# INFO:tensorflow:loss = 0.027759396, step = 19600 (6.977 sec)
# INFO:tensorflow:global_step/sec: 14.2562
# INFO:tensorflow:loss = 0.015212071, step = 19700 (7.015 sec)
# INFO:tensorflow:global_step/sec: 14.3509
# INFO:tensorflow:loss = 0.020234669, step = 19800 (6.964 sec)
# INFO:tensorflow:global_step/sec: 14.4094
# INFO:tensorflow:loss = 0.003498313, step = 19900 (6.943 sec)
# INFO:tensorflow:Saving checkpoints for 20000 into ./data_out/check_point/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.0005336101.

# %% [markdown]
# # 평가 하기

# %%
eval_result = classifier.evaluate(input_fn=lambda: data.eval_input_fn(
        eval_input_enc, eval_output_dec, eval_target_dec, DEFINES.batch_size))
print('\nEVAL set accuracy: {accuracy:0.3f}\n'.format(**eval_result))
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-03-27T02:07:59Z
# INFO:tensorflow:Graph was finalized.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from ./data_out/check_point/model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-03-27-02:08:02
# INFO:tensorflow:Saving dict for global step 20000: accuracy = 0.89084375, global_step = 20000, loss = 1.4210681
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 20000: ./data_out/check_point/model.ckpt-20000
#
# EVAL set accuracy: 0.891

# %% [markdown]
# # 테스트 하기

# %%
predic_input_enc, predic_input_enc_length = data.enc_processing(["행복하니?"], char2idx)
# 학습 과정이 아니므로 디코딩 입력은 
# 존재하지 않는다.(구조를 맞추기 위해 넣는다.)
predic_output_dec, predic_output_decLength = data.dec_output_processing([""], char2idx)
# 학습 과정이 아니므로 디코딩 출력 부분도 
# 존재하지 않는다.(구조를 맞추기 위해 넣는다.)
predic_target_dec = data.dec_target_processing([""], char2idx)   

for i in range(DEFINES.max_sequence_length):
    if i > 0:
        predic_output_dec, predic_output_decLength = data.dec_output_processing([answer], char2idx)
        predic_target_dec = data.dec_target_processing([answer], char2idx)
    # 예측을 하는 부분이다.
    predictions = classifier.predict(
        input_fn=lambda: data.eval_input_fn(predic_input_enc, predic_output_dec, predic_target_dec, 1))

    answer, finished = data.pred_next_string(predictions, idx2char)

    if finished:
        break

# 예측한 값을 인지 할 수 있도록
# 텍스트로 변경하는 부분이다.
print("answer: ", answer)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./data_out/check_point/model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./data_out/check_point/model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./data_out/check_point/model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./data_out/check_point/model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./data_out/check_point/model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./data_out/check_point/model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ./data_out/check_point/model.ckpt-20000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# answer:  남들이 안 하는게 서로에게 좋지 않아요
