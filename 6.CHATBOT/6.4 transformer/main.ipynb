# %% [markdown]
# # 패키지 불러오기

# %%
# !rm configs.py
# !rm data.py
# !rm main.py
# !rm model.py
# !rm predict.py



# !wget https://raw.githubusercontent.com/sjs2109/tensorflow-ml-nlp/master/6.CHATBOT/6.3%20seq2seq/configs.py .
# !wget https://raw.githubusercontent.com/sjs2109/tensorflow-ml-nlp/master/6.CHATBOT/6.3%20seq2seq/data.py
# !wget https://raw.githubusercontent.com/sjs2109/tensorflow-ml-nlp/master/6.CHATBOT/6.3%20seq2seq/main.py  
# !wget https://raw.githubusercontent.com/sjs2109/tensorflow-ml-nlp/master/6.CHATBOT/6.3%20seq2seq/model.py
# !wget https://raw.githubusercontent.com/sjs2109/tensorflow-ml-nlp/master/6.CHATBOT/6.3%20seq2seq/predict.py
# Out:
# --2019-03-25 00:16:04--  https://raw.githubusercontent.com/sjs2109/tensorflow-ml-nlp/master/6.CHATBOT/6.3%20seq2seq/configs.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1637 (1.6K) [text/plain]
# Saving to: ‘configs.py’
#
# configs.py          100%[===================>]   1.60K  --.-KB/s    in 0s
#
# 2019-03-25 00:16:05 (245 MB/s) - ‘configs.py’ saved [1637/1637]
#
# --2019-03-25 00:16:05--  http://./
# Resolving . (.)... failed: No address associated with hostname.
# wget: unable to resolve host address ‘.’
# FINISHED --2019-03-25 00:16:05--
# Total wall clock time: 0.07s
# Downloaded: 1 files, 1.6K in 0s (245 MB/s)
# --2019-03-25 00:16:06--  https://raw.githubusercontent.com/sjs2109/tensorflow-ml-nlp/master/6.CHATBOT/6.3%20seq2seq/data.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10840 (11K) [text/plain]
# Saving to: ‘data.py’
#
# data.py             100%[===================>]  10.59K  --.-KB/s    in 0s
#
# 2019-03-25 00:16:06 (106 MB/s) - ‘data.py’ saved [10840/10840]
#
# --2019-03-25 00:16:07--  https://raw.githubusercontent.com/sjs2109/tensorflow-ml-nlp/master/6.CHATBOT/6.3%20seq2seq/main.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3244 (3.2K) [text/plain]
# Saving to: ‘main.py’
#
# main.py             100%[===================>]   3.17K  --.-KB/s    in 0s
#
# 2019-03-25 00:16:07 (56.3 MB/s) - ‘main.py’ saved [3244/3244]
#
# --2019-03-25 00:16:09--  https://raw.githubusercontent.com/sjs2109/tensorflow-ml-nlp/master/6.CHATBOT/6.3%20seq2seq/model.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5588 (5.5K) [text/plain]
# Saving to: ‘model.py’
#
# model.py            100%[===================>]   5.46K  --.-KB/s    in 0s
#
# 2019-03-25 00:16:09 (68.6 MB/s) - ‘model.py’ saved [5588/5588]
#
# --2019-03-25 00:16:10--  https://raw.githubusercontent.com/sjs2109/tensorflow-ml-nlp/master/6.CHATBOT/6.3%20seq2seq/predict.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1582 (1.5K) [text/plain]
# Saving to: ‘predict.py’
#
# predict.py          100%[===================>]   1.54K  --.-KB/s    in 0s
#
# 2019-03-25 00:16:10 (216 MB/s) - ‘predict.py’ saved [1582/1582]

# %%
# !apt-get update

# !apt-get install g++ openjdk-8-jdk python-dev python3-dev

# !pip3 install JPype1-py3

# !pip3 install konlpy

# !JAVA_HOME="/usr/lib/jvm/java-8-openjdk-amd64"

import konlpy
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease [3,609 B]
# Get:3 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu bionic InRelease
# Ign:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Hit:9 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:10 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ Packages [58.4 kB]
# Get:11 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease [15.4 kB]
# Get:12 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [3,910 B]
# Get:13 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [361 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:15 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [159 kB]
# Get:16 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [31.0 kB]
# Get:19 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main Sources [1,627 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/multiverse amd64 Packages [6,968 B]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [952 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [725 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-backports/universe amd64 Packages [3,659 B]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-backports/main amd64 Packages [942 B]
# Get:25 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 Packages [782 kB]
# Fetched 5,002 kB in 4s (1,405 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# python-dev is already the newest version (2.7.15~rc1-1).
# g++ is already the newest version (4:7.3.0-3ubuntu2.1).
# g++ set to manually installed.
# python3-dev is already the newest version (3.6.7-1~18.04).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   fonts-dejavu-core fonts-dejavu-extra libatk-wrapper-java
#   libatk-wrapper-java-jni libxxf86dga1 openjdk-8-jre x11-utils
# Suggested packages:
#   openjdk-8-demo openjdk-8-source visualvm icedtea-8-plugin mesa-utils
# The following NEW packages will be installed:
#   fonts-dejavu-core fonts-dejavu-extra libatk-wrapper-java
#   libatk-wrapper-java-jni libxxf86dga1 openjdk-8-jdk openjdk-8-jre x11-utils
# 0 upgraded, 8 newly installed, 0 to remove and 123 not upgraded.
# Need to get 4,771 kB of archives.
# After this operation, 13.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxxf86dga1 amd64 2:1.1.4-1 [13.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-dejavu-core all 2.37-1 [1,041 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-dejavu-extra all 2.37-1 [1,953 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11-utils amd64 7.7+3build1 [196 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 libatk-wrapper-java all 0.33.3-20ubuntu0.1 [34.7 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 libatk-wrapper-java-jni amd64 0.33.3-20ubuntu0.1 [28.3 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 openjdk-8-jre amd64 8u191-b12-2ubuntu0.18.04.1 [69.7 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 openjdk-8-jdk amd64 8u191-b12-2ubuntu0.18.04.1 [1,435 kB]
# Fetched 4,771 kB in 1s (4,383 kB/s)
# Selecting previously unselected package libxxf86dga1:amd64.
# (Reading database ... 131323 files and directories currently installed.)
# Preparing to unpack .../0-libxxf86dga1_2%3a1.1.4-1_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.4-1) ...
# Selecting previously unselected package fonts-dejavu-core.
# Preparing to unpack .../1-fonts-dejavu-core_2.37-1_all.deb ...
# Unpacking fonts-dejavu-core (2.37-1) ...
# Selecting previously unselected package fonts-dejavu-extra.
# Preparing to unpack .../2-fonts-dejavu-extra_2.37-1_all.deb ...
# Unpacking fonts-dejavu-extra (2.37-1) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../3-x11-utils_7.7+3build1_amd64.deb ...
# Unpacking x11-utils (7.7+3build1) ...
# Selecting previously unselected package libatk-wrapper-java.
# Preparing to unpack .../4-libatk-wrapper-java_0.33.3-20ubuntu0.1_all.deb ...
# Unpacking libatk-wrapper-java (0.33.3-20ubuntu0.1) ...
# Selecting previously unselected package libatk-wrapper-java-jni:amd64.
# Preparing to unpack .../5-libatk-wrapper-java-jni_0.33.3-20ubuntu0.1_amd64.deb ...
# Unpacking libatk-wrapper-java-jni:amd64 (0.33.3-20ubuntu0.1) ...
# Selecting previously unselected package openjdk-8-jre:amd64.
# Preparing to unpack .../6-openjdk-8-jre_8u191-b12-2ubuntu0.18.04.1_amd64.deb ...
# Unpacking openjdk-8-jre:amd64 (8u191-b12-2ubuntu0.18.04.1) ...
# Selecting previously unselected package openjdk-8-jdk:amd64.
# Preparing to unpack .../7-openjdk-8-jdk_8u191-b12-2ubuntu0.18.04.1_amd64.deb ...
# Unpacking openjdk-8-jdk:amd64 (8u191-b12-2ubuntu0.18.04.1) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Setting up fonts-dejavu-core (2.37-1) ...
# Setting up libxxf86dga1:amd64 (2:1.1.4-1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Setting up fonts-dejavu-extra (2.37-1) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# Setting up x11-utils (7.7+3build1) ...
# Setting up libatk-wrapper-java (0.33.3-20ubuntu0.1) ...
# Setting up libatk-wrapper-java-jni:amd64 (0.33.3-20ubuntu0.1) ...
# Setting up openjdk-8-jre:amd64 (8u191-b12-2ubuntu0.18.04.1) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/policytool to provide /usr/bin/policytool (policytool) in auto mode
# Setting up openjdk-8-jdk:amd64 (8u191-b12-2ubuntu0.18.04.1) ...
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/appletviewer to provide /usr/bin/appletviewer (appletviewer) in auto mode
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/bin/jconsole to provide /usr/bin/jconsole (jconsole) in auto mode
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# Collecting JPype1-py3
#   Downloading https://files.pythonhosted.org/packages/59/90/149647ac2c8649a5983fcc47c78f2881af80cbd99f54248ac31b3d611618/JPype1-py3-0.5.5.2.tar.gz (87kB)
#     100% |████████████████████████████████| 92kB 3.9MB/s
# Building wheels for collected packages: JPype1-py3
#   Building wheel for JPype1-py3 (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/76/7d/41/829109c81b0c4bdca8047fb9e0a573d4db3b671fbbe84a84f3
# Successfully built JPype1-py3
# Installing collected packages: JPype1-py3
# Successfully installed JPype1-py3-0.5.5.2
# Collecting konlpy
#   Downloading https://files.pythonhosted.org/packages/e5/3d/4e983cd98d87b50b2ab0387d73fa946f745aa8164e8888a714d5129f9765/konlpy-0.5.1-py2.py3-none-any.whl (19.4MB)
#     100% |████████████████████████████████| 19.4MB 2.2MB/s
# Collecting JPype1>=0.5.7 (from konlpy)
#   Downloading https://files.pythonhosted.org/packages/c4/4b/60a3e63d51714d4d7ef1b1efdf84315d118a0a80a5b085bb52a7e2428cdc/JPype1-0.6.3.tar.gz (168kB)
#     100% |████████████████████████████████| 174kB 30.9MB/s
# Building wheels for collected packages: JPype1
#   Building wheel for JPype1 (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/0e/2b/e8/c0b818ac4b3d35104d35e48cdc7afe27fc06ea277feed2831a
# Successfully built JPype1
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-0.6.3 konlpy-0.5.1

# %%
import tensorflow as tf
import model as ml
import data
import numpy as np
import os
import sys

from configs import DEFINES

# %% [markdown]
# # 사전 만들기

# %%
# !rm -rf ../data_in
# !mkdir ../data_in
# !wget https://raw.githubusercontent.com/sjs2109/tensorflow-ml-nlp/master/6.CHATBOT/data_in/ChatBotData.csv -P ../data_in
# Out:
# --2019-03-25 00:23:02--  https://raw.githubusercontent.com/sjs2109/tensorflow-ml-nlp/master/6.CHATBOT/data_in/ChatBotData.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 889842 (869K) [text/plain]
# Saving to: ‘../data_in/ChatBotData.csv’
#
# ChatBotData.csv     100%[===================>] 868.99K  --.-KB/s    in 0.06s
#
# 2019-03-25 00:23:02 (13.5 MB/s) - ‘../data_in/ChatBotData.csv’ saved [889842/889842]

# %%
DATA_OUT_PATH = './data_out/'
data_out_path = os.path.join(os.getcwd(), DATA_OUT_PATH)
os.makedirs(data_out_path, exist_ok=True)
char2idx,  idx2char, vocabulary_length = data.load_vocabulary()
# Out:
# 100%|██████████| 11823/11823 [00:36<00:00, 326.83it/s]
# 100%|██████████| 11823/11823 [00:47<00:00, 251.22it/s]

# %% [markdown]
# # 데이터 만들기

# %%
# !grep -rn UNKNOWN *

# %%
char2idx
# Out:
# {'<PADDING>': 0,
#  '<START>': 1,
#  '<END>': 2,
#  '<UNKNOWN>': 3,
#  '나화': 4,
#  '잘살았는데': 5,
#  '싶지': 6,
#  '입대': 7,
#  '알려줘요': 8,
#  '찍어주세요': 9,
#  '숨막히네': 10,
#  '선생님': 11,
#  '견디는수밖에': 12,
#  '빼야': 13,
#  '힌트': 14,
#  '필요하겠지': 15,
#  '않을지도': 16,
#  '나오겠네요': 17,
#  '균형': 18,
#  '클럽': 19,
#  '옆': 20,
#  '비싸': 21,
#  '똑같은가': 22,
#  '했습니다': 23,
#  '헷갈리나요': 24,
#  '북': 25,
#  '되었': 26,
#  '치열해지는것': 27,
#  '움직임': 28,
#  '즐거워지겠네요': 29,
#  '듣지': 30,
#  '입을거': 31,
#  '없다가있어서': 32,
#  '뜰거예요': 33,
#  '다신': 34,
#  '어리게': 35,
#  '가고있어': 36,
#  '먹기': 37,
#  '받고야말았네': 38,
#  '했을까요': 39,
#  '반했나': 40,
#  '봤지요': 41,
#  '효도': 42,
#  '아낌없이퍼주는': 43,
#  '높아서': 44,
#  '넓답니다': 45,
#  '기침': 46,
#  '느껴': 47,
#  '안되어있는데': 48,
#  '귀엽다고': 49,
#  '가네요': 50,
#  '호감': 51,
#  '살고있어': 52,
#  '영향': 53,
#  '허락': 54,
#  '이최선': 55,
#  '영원했으면': 56,
#  '행복해하는걸': 57,
#  '붙잡으세요': 58,
#  '친해지는게': 59,
#  '붙으로': 60,
#  '깐깐해': 61,
#  '전여자친구': 62,
#  '였겠지': 63,
#  '모르네': 64,
#  '변하니': 65,
#  '어째서': 66,
#  '줄여야겠어': 67,
#  '그치는것은고': 68,
#  '같다고': 69,
#  '재밌을듯': 70,
#  '진지한': 71,
#  '청결한': 72,
#  '관리': 73,
#  '남기지': 74,
#  '했었으니까': 75,
#  '내릴수있다면노': 76,
#  '축구': 77,
#  '되어주고있나': 78,
#  '가해준': 79,
#  '뻔했네': 80,
#  '죽겠네': 81,
#  '지우지못': 82,
#  '끝내더라': 83,
#  '래지': 84,
#  '빠지면': 85,
#  '인정받을수있을까': 86,
#  '찾아가도': 87,
#  '하고자면': 88,
#  '없던가요': 89,
#  '없다는데': 90,
#  '들어야해': 91,
#  '마셔야겠다': 92,
#  '많으시군요': 93,
#  '종이': 94,
#  '붙였던': 95,
#  '만남이네요': 96,
#  '안좋': 97,
#  '허전할거': 98,
#  '중요한건데': 99,
#  '내기억': 100,
#  '효녀': 101,
#  '휴식': 102,
#  '모르죠': 103,
#  '처음': 104,
#  '있다는걸': 105,
#  '잼': 106,
#  '해줄수있는것': 107,
#  '그렇진': 108,
#  '없겠지요': 109,
#  '어려': 110,
#  '이되어갑니다': 111,
#  '무게': 112,
#  '출퇴근': 113,
#  '비결': 114,
#  '팍팍': 115,
#  '그만둘래': 116,
#  '상치': 117,
#  '만의연애가끝났네': 118,
#  '로서': 119,
#  '인연': 120,
#  '다른사람': 121,
#  '빽': 122,
#  '입는거': 123,
#  '마시는': 124,
#  '묻어': 125,
#  '도망가라는': 126,
#  '하셔요': 127,
#  '영영': 128,
#  '엄청': 129,
#  '나안': 130,
#  '또힘': 131,
#  '얼마': 132,
#  '썸인데나': 133,
#  '끝나길': 134,
#  '그러자': 135,
#  '가아니에요': 136,
#  '사주': 137,
#  '이길어요': 138,
#  '도색': 139,
#  '지안': 140,
#  '헤어졌나': 141,
#  '낼수있는': 142,
#  '뭣': 143,
#  '멘붕': 144,
#  '아파하지': 145,
#  '앉은듯': 146,
#  '했내': 147,
#  '코인': 148,
#  '들어올까': 149,
#  '우울증': 150,
#  '미련': 151,
#  '받아들인다는것': 152,
#  '하셔도': 153,
#  '만자세요': 154,
#  '든든할거예요': 155,
#  '백': 156,
#  '아닌거': 157,
#  '않는데': 158,
#  '그렇겠죠': 159,
#  '머': 160,
#  '안함': 161,
#  '지친거': 162,
#  '생각나는데': 163,
#  '잡았다고': 164,
#  '이겨야': 165,
#  '간사하게': 166,
#  '짜오': 167,
#  '인': 168,
#  '어려워': 169,
#  '보안': 170,
#  '시원하네요': 171,
#  '줘서': 172,
#  '예뻐지나': 173,
#  '새살': 174,
#  '웃을줄': 175,
#  '만에연락그후입니다': 176,
#  '않았는지': 177,
#  '주말전에': 178,
#  '모자라': 179,
#  '달이': 180,
#  '라이트': 181,
#  '힘내려': 182,
#  '부려': 183,
#  '서툰게': 184,
#  '하다니': 185,
#  '하고잘': 186,
#  '똑같지': 187,
#  '웃으며': 188,
#  '두보': 189,
#  '참아야겠죠': 190,
#  '후련하기도': 191,
#  '충전기': 192,
#  '이었을까요': 193,
#  '차네': 194,
#  '까먹고안': 195,
#  '착할거': 196,
#  '뭐라': 197,
#  '깨지고있네요': 198,
#  '굳건': 199,
#  '났나': 200,
#  '품다': 201,
#  '맞는거': 202,
#  '지나고나서': 203,
#  '건뭘': 204,
#  '아팠으면': 205,
#  '억울하다': 206,
#  '자금': 207,
#  '미운': 208,
#  '이상했겠어요': 209,
#  '똑똑한': 210,
#  '채널': 211,
#  '찾아볼까': 212,
#  '구': 213,
#  '말실수': 214,
#  '살아가고': 215,
#  '변신': 216,
#  '창문': 217,
#  '걸안': 218,
#  '그런건': 219,
#  '힘들기': 220,
#  '알려주세요': 221,
#  '욕먹는거': 222,
#  '나쁜건': 223,
#  '꾸준히': 224,
#  '봐주세요': 225,
#  '먹고싶아': 226,
#  '짓을하고': 227,
#  '돌담': 228,
#  '이상하면': 229,
#  '차이가있을': 230,
#  '보냈네': 231,
#  '건강하고': 232,
#  '먹네': 233,
#  '아이구': 234,
#  '고이': 235,
#  '걸릴지도': 236,
#  '성숙한': 237,
#  '단톡': 238,
#  '도와줄까': 239,
#  '끝나가니': 240,
#  '스타트업': 241,
#  'as': 242,
#  '더크': 243,
#  '찍고오세요': 244,
#  '전환': 245,
#  '양면': 246,
#  '기다리고있을거예요': 247,
#  '보지말아야하나': 248,
#  '기획사': 249,
#  '하기는해': 250,
#  '석': 251,
#  '질렀어': 252,
#  '랜선': 253,
#  '베트남어': 254,
#  '대적': 255,
#  '확실하진': 256,
#  '들지만': 257,
#  '진짜': 258,
#  '불금': 259,
#  '꿈꿎': 260,
#  '즐거운게': 261,
#  '달끝': 262,
#  '살쪄서': 263,
#  '남겠네요': 264,
#  '다시말': 265,
#  '숙취': 266,
#  '젹': 267,
#  '멀고해': 268,
#  '흔들리죠': 269,
#  '거둘거예요': 270,
#  '있니': 271,
#  '그리워지나요': 272,
#  '건지': 273,
#  '기예': 274,
#  '나빴네': 275,
#  '그대': 276,
#  '들려주세요': 277,
#  '기대합니다': 278,
#  '안고': 279,
#  '물어봐': 280,
#  '받고있는': 281,
#  '보낼려': 282,
#  '대머리': 283,
#  '이욕': 284,
#  '기다렸는데': 285,
#  '작아지는데': 286,
#  '찍었어': 287,
#  '간절함이': 288,
#  '높나': 289,
#  '15일': 290,
#  '나오고': 291,
#  '되면': 292,
#  '서적': 293,
#  '쉬어가는건': 294,
#  '매일': 295,
#  '하울': 296,
#  '깔끔해질': 297,
#  '펴고': 298,
#  '좀줄었으면': 299,
#  '앞서서': 300,
#  '예뻐': 301,
#  '아프잖아': 302,
#  '감기가오려나': 303,
#  '어려지고': 304,
#  '추워서': 305,
#  '잘가': 306,
#  '부족했네요': 307,
#  '더하면': 308,
#  '느껴진다는': 309,
#  '생각날거예요': 310,
#  '그렇게': 311,
#  '하객': 312,
#  '끓여서': 313,
#  '사귈수있을까요': 314,
#  '머리카락': 315,
#  '먹고자도': 316,
#  '들어주기도': 317,
#  '멀어지지': 318,
#  '들거예요': 319,
#  '찔려': 320,
#  '같은거있나': 321,
#  '건강': 322,
#  '쪽팔린': 323,
#  '아는데도': 324,
#  '싫더라고요': 325,
#  '돌려말하는걸': 326,
#  '물마': 327,
#  '갈거예요': 328,
#  '위통': 329,
#  '될줄': 330,
#  '헤어졌다는': 331,
#  '대리': 332,
#  '보여주고싶어': 333,
#  '이기': 334,
#  '정상': 335,
#  '집안': 336,
#  '라는': 337,
#  '얼른주': 338,
#  '흐르고다시': 339,
#  '받는거': 340,
#  '좋아하고있었어': 341,
#  '읽다가': 342,
#  '편해지겠지': 343,
#  '거': 344,
#  '식도염': 345,
#  '허전함이': 346,
#  '참견': 347,
#  '빼앗겼다고': 348,
#  '순간': 349,
#  '집들이': 350,
#  '허무해': 351,
#  '사귀기로': 352,
#  '뺏길거': 353,
#  '툭툭': 354,
#  '해봤는데안': 355,
#  '반의만남끝에헤어지게되었습니다': 356,
#  '떠났네': 357,
#  '나는못': 358,
#  '이고': 359,
#  '좀질': 360,
#  '이럴까': 361,
#  '해탈': 362,
#  '해줄수있어요': 363,
#  '소나기': 364,
#  '마실수있어요': 365,
#  '막힌다': 366,
#  '잘살겠지라고': 367,
#  '흔들리겠어요': 368,
#  '만남긴': 369,
#  '간단하게': 370,
#  '않은데못': 371,
#  '하는것에서부터': 372,
#  '날까': 373,
#  '좋지요': 374,
#  '삼십': 375,
#  '헤어지지못': 376,
#  '행복하고': 377,
#  '타는거': 378,
#  '했군요': 379,
#  '지네': 380,
#  '좀구': 381,
#  '놀더군': 382,
#  '그럴': 383,
#  '스러울거예요': 384,
#  '불공평한거': 385,
#  '바랄세요': 386,
#  '다는': 387,
#  '방탈출게임': 388,
#  '푹쉬세요': 389,
#  '자면': 390,
#  '어리석': 391,
#  '세는건': 392,
#  '하려다': 393,
#  '않았으면': 394,
#  '쌓여': 395,
#  '받아는': 396,
#  '지궁': 397,
#  '야하는거아니야': 398,
#  '매세요': 399,
#  '되어있지': 400,
#  '먹은대로': 401,
#  '고히': 402,
#  '하니': 403,
#  '먹었니': 404,
#  '쓰는': 405,
#  '나는아': 406,
#  '변했다고': 407,
#  '보시': 408,
#  '헤어진지': 409,
#  '좀고치고': 410,
#  '노래있으': 411,
#  '일단': 412,
#  '몰랐어요': 413,
#  '프랑': 414,
#  '다가가야겠죠': 415,
#  '생활용품': 416,
#  '학부모': 417,
#  '공통': 418,
#  '초해': 419,
#  '젊게': 420,
#  '놀고싶어': 421,
#  '갈데가': 422,
#  '예민해져': 423,
#  '후난': 424,
#  '처리': 425,
#  '전화했어': 426,
#  '바닥': 427,
#  '무모함': 428,
#  '터질것만': 429,
#  '살수있을지': 430,
#  '지나': 431,
#  '취향': 432,
#  '불가한': 433,
#  '썼는데': 434,
#  '무너진': 435,
#  '집콕': 436,
#  '바빠졌으면': 437,
#  '않았을거라': 438,
#  '괜찮아지세요': 439,
#  '떠보는것보다': 440,
#  '믿게': 441,
#  '시원한': 442,
#  '어렵네': 443,
#  '을': 444,
#  '구워': 445,
#  '바로': 446,
#  '춥고': 447,
#  '없': 448,
#  '치열하죠': 449,
#  '갑자기': 450,
#  '피피': 451,
#  '되셨어': 452,
#  '벌었어': 453,
#  '좋지': 454,
#  '않게': 455,
#  '지마': 456,
#  '깨는': 457,
#  '만든': 458,
#  '졸게되': 459,
#  '빠졌죠': 460,
#  '들킨거': 461,
#  '같길': 462,
#  '댄디': 463,
#  '먹어': 464,
#  'jk': 465,
#  '태어나면': 466,
#  '떨어져': 467,
#  '좀넘은저의사랑그리고이별이야기': 468,
#  '거너': 469,
#  '백만': 470,
#  '있는것같이': 471,
#  '밑바닥': 472,
#  '가려하는데': 473,
#  '두렵네': 474,
#  '걷고': 475,
#  '노잼': 476,
#  '받는것도': 477,
#  '결재': 478,
#  '내전': 479,
#  '놀았는데': 480,
#  '뜨거운': 481,
#  '방심했어': 482,
#  '끝나': 483,
#  '그리움': 484,
#  '헤어지': 485,
#  '식초': 486,
#  '됐는데': 487,
#  '게스트하우스': 488,
#  '땀을내': 489,
#  '쪽지': 490,
#  '있겠어요': 491,
#  '왜애': 492,
#  '먹하네': 493,
#  '가리는': 494,
#  '탱': 495,
#  '과거': 496,
#  '난치': 497,
#  '고를수도': 498,
#  '도하': 499,
#  '차는': 500,
#  '이모티콘': 501,
#  '힘들면': 502,
#  '해야겠죠': 503,
#  '빚': 504,
#  '순수했던걸': 505,
#  '반': 506,
#  '오랫동안': 507,
#  '이었을까': 508,
#  '뒀으면': 509,
#  '좋아하시나': 510,
#  '떨까': 511,
#  '무색': 512,
#  '간지러': 513,
#  '또못': 514,
#  '끈이있을까': 515,
#  '씻기': 516,
#  '기대도': 517,
#  '다양하다고': 518,
#  '별': 519,
#  '막혔는데': 520,
#  '꿈': 521,
#  '공률': 522,
#  '사야': 523,
#  '바람': 524,
#  '삼주라는': 525,
#  '잠자리': 526,
#  '마라톤': 527,
#  '적응하고': 528,
#  '그만두고': 529,
#  '하느냐에': 530,
#  '이따': 531,
#  '야해서': 532,
#  '헤어짐을말하려': 533,
#  '선배': 534,
#  '다': 535,
#  '효율': 536,
#  '아프겠어요': 537,
#  '내가이래': 538,
#  '알고있을까': 539,
#  '프로필': 540,
#  '후련해지길': 541,
#  '변해가요': 542,
#  '30분': 543,
#  '손목': 544,
#  '회복할수있을까': 545,
#  '즐기나': 546,
#  '서류': 547,
#  '신다운': 548,
#  '여유': 549,
#  '비슷한': 550,
#  '흘러갑니다': 551,
#  '옳소': 552,
#  '건아': 553,
#  '힘들어지네': 554,
#  '칼국수': 555,
#  '어느': 556,
#  '만나러가': 557,
#  '썸': 558,
#  '닦아주고싶네요': 559,
#  '글귀': 560,
#  '감수': 561,
#  '맨몸': 562,
#  '데려다주려고': 563,
#  '납니다': 564,
#  '멋있어': 565,
#  '넘었어': 566,
#  '마주치는게': 567,
#  '올라와': 568,
#  '정열': 569,
#  '아쉽지만': 570,
#  '쓰이나': 571,
#  '슬프구': 572,
#  '내립니다': 573,
#  '걸이': 574,
#  '의병': 575,
#  '쉬셔': 576,
#  '달라는데': 577,
#  '별똥별': 578,
#  '인가보다': 579,
#  '난아니라네': 580,
#  '보내지못하는': 581,
#  '정도놀러가고싶다': 582,
#  '그렇다': 583,
#  '쫌': 584,
#  '에궁': 585,
#  '말하지못하는사': 586,
#  '어떠하죠': 587,
#  '짜증': 588,
#  '느낀게': 589,
#  '받지도': 590,
#  '조용한': 591,
#  '흔들리지': 592,
#  '만들기': 593,
#  '쏟아지고있군요': 594,
#  '발견': 595,
#  '떨리나': 596,
#  '없다가도': 597,
#  '전그녀에게고백했던날': 598,
#  '몰랐나': 599,
#  '많다': 600,
#  '독한것도': 601,
#  '자세히': 602,
#  '버텻': 603,
#  '둘다에게': 604,
#  '있는거죠': 605,
#  '덜하면': 606,
#  '감추는게': 607,
#  '에의': 608,
#  '허기진다': 609,
#  '내려가서': 610,
#  '볼수도': 611,
#  '넘겨보세요': 612,
#  '중요한것': 613,
#  '유부': 614,
#  '짧아': 615,
#  '잘하셨어요': 616,
#  '키워': 617,
#  '헤어지고만': 618,
#  '남이있는데나는사': 619,
#  '봄이오길': 620,
#  '했었네': 621,
#  '멋있네요': 622,
#  '가봅니다': 623,
#  '마보이': 624,
#  '흔들리고있나요': 625,
#  '독하게': 626,
#  '맛있죠': 627,
#  '이편': 628,
#  '중요할거예요': 629,
#  '어렵겠지': 630,
#  '소개팅': 631,
#  '만남이있으면': 632,
#  '받아들이는건': 633,
#  '써야겠다': 634,
#  '등록금': 635,
#  '찾아가야해': 636,
#  '정리': 637,
#  '징글징글': 638,
#  '해낸': 639,
#  '부로': 640,
#  '애틋하게되': 641,
#  '데려다': 642,
#  '받았는데': 643,
#  '다니시나': 644,
#  '멀어지는길': 645,
#  '번의': 646,
#  '찍었습니다': 647,
#  '모르는': 648,
#  '맞겠지': 649,
#  '끝났지': 650,
#  '스키장': 651,
#  '떠나지': 652,
#  '헤어짐과': 653,
#  '문화센터': 654,
#  '방면': 655,
#  '는데': 656,
#  '나갈게': 657,
#  '는해': 658,
#  '들음': 659,
#  '없었는데': 660,
#  '이상하게이': 661,
#  '못자는데': 662,
#  '많았어요': 663,
#  '사랑받고있다는걸': 664,
#  '따져요': 665,
#  '로이': 666,
#  '그동안': 667,
#  '필요했을지도': 668,
#  '이여기': 669,
#  '보면서': 670,
#  '변하니까': 671,
#  '폭식증': 672,
#  '포근하죠': 673,
#  '좋아하게하지': 674,
#  '생겼으면': 675,
#  '그런거니': 676,
#  '기다린다는게': 677,
#  '착하긴한데': 678,
#  '사귀다': 679,
#  '에도': 680,
#  '편': 681,
#  '혼날텐데': 682,
#  '되죠': 683,
#  '무서워': 684,
#  '해가지는게': 685,
#  '많았겠죠': 686,
#  '살아가곤': 687,
#  '후련하다니': 688,
#  '개학': 689,
#  '있네': 690,
#  '편할거': 691,
#  '떨쳐': 692,
#  '만들어가는거예요': 693,
#  '따였어': 694,
#  '작년': 695,
#  '쌓이': 696,
#  '도충': 697,
#  '에서만': 698,
#  '할수있음': 699,
#  '시간표': 700,
#  '글쎄요': 701,
#  '다르겠지요': 702,
#  '들어온다': 703,
#  '주절주절': 704,
#  '떠납니다': 705,
#  '너무하다싶을': 706,
#  '써져': 707,
#  '집구': 708,
#  '명언': 709,
#  '사로잡는': 710,
#  '친해질수있는': 711,
#  '나타나니': 712,
#  '할수있어요': 713,
#  '공시생': 714,
#  '치료받아야': 715,
#  '할말이': 716,
#  '제약': 717,
#  '야': 718,
#  '죽고싶다는': 719,
#  '보내고': 720,
#  '당연히': 721,
#  '고함': 722,
#  '보려하는데': 723,
#  '아무리': 724,
#  '달래기': 725,
#  '보셔요': 726,
#  '뭐라고답': 727,
#  '만나요': 728,
#  '새집': 729,
#  '사하려고': 730,
#  '즐기면': 731,
#  '손가락': 732,
#  '마시고있네': 733,
#  '않았기': 734,
#  '팔아서': 735,
#  '잊기로': 736,
#  '남은걸': 737,
#  '안좋아': 738,
#  '과외': 739,
#  '은퇴': 740,
#  '진실로': 741,
#  '참아야하나': 742,
#  '담긴것을': 743,
#  '웁니': 744,
#  '할수있겠지': 745,
#  '덥다': 746,
#  '무너지네': 747,
#  '볼텐데': 748,
#  '서면말이안나와': 749,
#  '각지': 750,
#  '이를지도': 751,
#  '헤어지고다시': 752,
#  '냉정해진다': 753,
#  '넓으신': 754,
#  '만들어줄까': 755,
#  '화하는것만': 756,
#  '날텐데': 757,
#  '받고싶어': 758,
#  '보여주지못하니': 759,
#  '받아들이세요': 760,
#  '알고싶다': 761,
#  '만나고있어': 762,
#  '다가가면': 763,
#  '만나고싶다': 764,
#  '하트': 765,
#  '덤덤한': 766,
#  '공항': 767,
#  '할수록': 768,
#  '남네': 769,
#  '머릿결좀': 770,
#  '교직이수': 771,
#  '늘어지네': 772,
#  '자연스러운': 773,
#  '장하는거': 774,
#  '놓아주': 775,
#  '만나다': 776,
#  '나쁜듯': 777,
#  '있을거예요': 778,
#  '들이있더라고요': 779,
#  '있었으면': 780,
#  '잡고싶지만': 781,
#  '금일': 782,
#  '입안': 783,
#  '숙제': 784,
#  '째되어가네': 785,
#  '솔직해지세요': 786,
#  '무제': 787,
#  '살아서': 788,
#  '타협': 789,
#  '오싹한': 790,
#  '예쁠까': 791,
#  '둘이하니': 792,
#  '이었으지도': 793,
#  '래': 794,
#  '추가': 795,
#  '잘라야지': 796,
#  '헤어짐에': 797,
#  '꺼져': 798,
#  '귀찮네': 799,
#  '다르지': 800,
#  '맞아서': 801,
#  '척': 802,
#  '8년': 803,
#  '좋아하게': 804,
#  'SNS': 805,
#  '가면있는': 806,
#  '해봅니다': 807,
#  '자책': 808,
#  '충분히': 809,
#  '만나야': 810,
#  '분명': 811,
#  '쥬스': 812,
#  '조심스러울거예요': 813,
#  '까지': 814,
#  '들이긴': 815,
#  '부케': 816,
#  '안되는거': 817,
#  '한계': 818,
#  '주는데': 819,
#  '종지부': 820,
#  '정량': 821,
#  '다가와주는': 822,
#  '설렜을텐데': 823,
#  '않을수도': 824,
#  '지나간다': 825,
#  '사흘': 826,
#  '좋더라': 827,
#  '유도기': 828,
#  '진급': 829,
#  '본심': 830,
#  '평가': 831,
#  '젖는듯': 832,
#  '가까이': 833,
#  '쓴지': 834,
#  '살찔거': 835,
#  '보내야하는데': 836,
#  '스노클링': 837,
#  '할라': 838,
#  '괴로웠을거라': 839,
#  '태고': 840,
#  '쥐고있어야': 841,
#  '귤': 842,
#  '건조하네': 843,
#  '추억': 844,
#  '모르고': 845,
#  '보낼수': 846,
#  '바라보고있길': 847,
#  '걷고있어': 848,
#  '바꾸는게': 849,
#  '비공개': 850,
#  '혼내는': 851,
#  '사드': 852,
#  '건강한': 853,
#  '사는거도': 854,
#  '싸워': 855,
#  '힘들겠어요': 856,
#  '흐르네': 857,
#  '떠나고싶어': 858,
#  '긴만남의끝은힘드네': 859,
#  '좋긴': 860,
#  '찾아오길': 861,
#  '흐르면': 862,
#  '빛나지요': 863,
#  '깨다해': 864,
#  '쌩깠어': 865,
#  '해야하는거니': 866,
#  '겁니다': 867,
#  '욕좀': 868,
#  '알아봐주는': 869,
#  '빗': 870,
#  '샀어': 871,
#  '엄마': 872,
#  '하는사': 873,
#  '쌓였네': 874,
#  '달콤한말이네요': 875,
#  '중요한데말이죠': 876,
#  '우선': 877,
#  '이허': 878,
#  '물어보렴': 879,
#  '잘맞아서': 880,
#  '가지고있네요': 881,
#  '마음속': 882,
#  '남여': 883,
#  '완전하게': 884,
#  '본적': 885,
#  '빨간': 886,
#  '주름': 887,
#  '바꿔': 888,
#  '왤': 889,
#  '다크서클': 890,
#  '몰라줘도': 891,
#  '더울어도': 892,
#  '힘든거는': 893,
#  '보증금': 894,
#  '억울한': 895,
#  '볼링': 896,
#  '귀찮게': 897,
#  '기계사': 898,
#  '해주던': 899,
#  '반가워요': 900,
#  '됐습니다': 901,
#  '버리는건': 902,
#  '안되는군': 903,
#  '똑같아': 904,
#  '탔어': 905,
#  '좋았겠어요': 906,
#  '가의': 907,
#  '겪는': 908,
#  '맘전': 909,
#  '넘었고': 910,
#  '빠지고싶다': 911,
#  '떨어요': 912,
#  '찌는게': 913,
#  '질려하나': 914,
#  '괜': 915,
#  '익숨함': 916,
#  '보고있네요': 917,
#  '먹고가요': 918,
#  '아픔이있는데': 919,
#  '떨칠수도': 920,
#  '남았어도': 921,
#  '낸다면': 922,
#  '날뭐': 923,
#  '될거야': 924,
#  '대요': 925,
#  '볼래요': 926,
#  '거드세요': 927,
#  '애완동물': 928,
#  '예쁘면다냐': 929,
#  '필요하대': 930,
#  '열림': 931,
#  '시켰어': 932,
#  '파란하늘': 933,
#  '줌': 934,
#  '달라': 935,
#  '써야하는게': 936,
#  '하고싶어지네': 937,
#  '응': 938,
#  '단체': 939,
#  '이진': 940,
#  '차로': 941,
#  '돌아온': 942,
#  '뭐말': 943,
#  '기다리는건': 944,
#  '일것': 945,
#  '끊기는거': 946,
#  '황당해서말도': 947,
#  '안녕하세': 948,
#  '오는건': 949,
#  '흘렀습니다': 950,
#  '좋겠다': 951,
#  '까': 952,
#  '좋아할거예요': 953,
#  '답니': 954,
#  '맞자': 955,
#  '기전': 956,
#  '일어났더니': 957,
#  '느꼈나': 958,
#  '보고싶으면': 959,
#  '달도': 960,
#  '이혼': 961,
#  '볼매': 962,
#  '서애': 963,
#  '먹으': 964,
#  '빌게요': 965,
#  '도썸': 966,
#  '쓰는건': 967,
#  '클': 968,
#  '올텐데': 969,
#  '객관': 970,
#  '울적해서': 971,
#  '떠나요': 972,
#  '견뎌내고있어요': 973,
#  '챙긴다는': 974,
#  '보였나': 975,
#  '만들어요': 976,
#  '물건': 977,
#  '배부르고': 978,
#  '떨어져있으면': 979,
#  '많지': 980,
#  '꿈뭘': 981,
#  '한지': 982,
#  '만나자면': 983,
#  '치는': 984,
#  '죽진못하겠구': 985,
#  '딸까': 986,
#  '얼른나으세요': 987,
#  '애착': 988,
#  '실망했어요': 989,
#  '온다면나는세시부터': 990,
#  '예쁘다': 991,
#  '그러는것': 992,
#  '괜찮아지고있어요': 993,
#  '대출받아도': 994,
#  '강제': 995,
#  '솔직했으면': 996,
#  '소문날까': 997,
#  '전문가': 998,
#  '생각': 999,
#  ...}

# %%
train_input, train_label, eval_input, eval_label = data.load_data()

#TODO3: 실행 안됨, 실행 후 지속적으로 리뷰하겠음

# 훈련셋 인코딩 만드는 부분이다.
train_input_enc, train_input_enc_length = data.enc_processing(train_input, char2idx)
# 훈련셋 디코딩 입력 부분 만드는 부분이다.
train_output_dec, train_output_dec_length = data.dec_input_processing(train_label, char2idx) #TODO1 실행 안되어 확인 필요(AttributeError: module 'data' has no attribute 'dec_output_processing)
# 훈련셋 디코딩 출력 부분 만드는 부분이다.
train_target_dec = data.dec_target_processing(train_label, char2idx)

# 평가셋 인코딩 만드는 부분이다.
eval_input_enc, eval_input_enc_length = data.enc_processing(eval_input,char2idx)
# 평가셋 인코딩 만드는 부분이다.
eval_output_dec, eval_output_dec_length = data.dec_input_processing(eval_label, char2idx)
# 평가셋 인코딩 만드는 부분이다.
eval_target_dec = data.dec_target_processing(eval_label, char2idx)
# Out:
# 100%|██████████| 7921/7921 [00:24<00:00, 326.91it/s]
# 100%|██████████| 7921/7921 [00:31<00:00, 248.92it/s]
# 100%|██████████| 7921/7921 [00:31<00:00, 249.88it/s]
# 100%|██████████| 3902/3902 [00:11<00:00, 326.81it/s]
# 100%|██████████| 3902/3902 [00:15<00:00, 253.75it/s]
# 100%|██████████| 3902/3902 [00:15<00:00, 253.85it/s]

# %% [markdown]
# # 체크 포인트 경로 만들기

# %%
# 현재 경로'./'에 현재 경로 하부에 
# 체크 포인트를 저장한 디렉토리를 설정한다.
check_point_path = os.path.join(os.getcwd(), DEFINES.check_point_path)
# 디렉토리를 만드는 함수이며 두번째 인자 exist_ok가 
# True이면 디렉토리가 이미 존재해도 OSError가 
# 발생하지 않는다.
# exist_ok가 False이면 이미 존재하면 
# OSError가 발생한다.
os.makedirs(check_point_path, exist_ok=True)

# %% [markdown]
# # 에스티 메이터 구성

# %%
# 에스티메이터 구성한다.

# TODO2: 왜 분류모델이라고 적혀있나요???? s2s이 아닌가요?

classifier = tf.estimator.Estimator(
        model_fn=ml.model, # 모델 등록한다.
        model_dir=DEFINES.check_point_path, # 체크포인트 위치 등록한다.
        params={ # 모델 쪽으로 파라메터 전달한다.
            'hidden_size': DEFINES.hidden_size, # 가중치 크기 설정한다.
            'layer_size': DEFINES.layer_size, # 멀티 레이어 층 개수를 설정한다.
            'learning_rate': DEFINES.learning_rate, # 학습율 설정한다. 
            'vocabulary_length': vocabulary_length, # 딕셔너리 크기를 설정한다.
            'embedding_size': DEFINES.embedding_size, # 임베딩 크기를 설정한다.
            'embedding': DEFINES.embedding, # 임베딩 사용 유무를 설정한다.
            'multilayer': DEFINES.multilayer, # 멀티 레이어 사용 유무를 설정한다.
        })
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': './data_out/check_point', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f3b96e6beb8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %% [markdown]
# # 학습 실행

# %%
# 학습 실행
classifier.train(input_fn=lambda:data.train_input_fn(
    train_input_enc, train_output_dec, train_target_dec,  DEFINES.batch_size), steps=DEFINES.train_steps)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# INFO:tensorflow:Calling model_fn.
#
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /content/model.py:9: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /content/model.py:49: MultiRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /content/model.py:57: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/rnn_cell_impl.py:1259: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /content/model.py:74: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/metrics_impl.py:455: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ./data_out/check_point/model.ckpt.
# INFO:tensorflow:loss = 9.660334, step = 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-466c79b13a87> in <module>()
#       1 classifier.train(input_fn=lambda:data.train_input_fn(
# ----> 2     train_input_enc, train_output_dec, train_target_dec,  DEFINES.batch_size), steps=DEFINES.train_steps)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     356
#     357       saving_listeners = _check_listeners_type(saving_listeners)
# --> 358       loss = self._train_model(input_fn, hooks, saving_listeners)
#     359       logging.info('Loss for final step: %s.', loss)
#     360       return self
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#    1122       return self._train_model_distributed(input_fn, hooks, saving_listeners)
#    1123     else:
# -> 1124       return self._train_model_default(input_fn, hooks, saving_listeners)
#    1125
#    1126   def _train_model_default(self, input_fn, hooks, saving_listeners):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/estimator.py in _train_model_default(self, input_fn, hooks, saving_listeners)
#    1156       return self._train_with_estimator_spec(estimator_spec, worker_hooks,
#    1157                                              hooks, global_step_tensor,
# -> 1158                                              saving_listeners)
#    1159
#    1160   def _train_model_distributed(self, input_fn, hooks, saving_listeners):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow_estimator/python/estimator/estimator.py in _train_with_estimator_spec(self, estimator_spec, worker_hooks, hooks, global_step_tensor, saving_listeners)
#    1405       any_step_done = False
#    1406       while not mon_sess.should_stop():
# -> 1407         _, loss = mon_sess.run([estimator_spec.train_op, estimator_spec.loss])
#    1408         any_step_done = True
#    1409     if not any_step_done:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#     674                           feed_dict=feed_dict,
#     675                           options=options,
# --> 676                           run_metadata=run_metadata)
#     677
#     678   def run_step_fn(self, step_fn):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1169                               feed_dict=feed_dict,
#    1170                               options=options,
# -> 1171                               run_metadata=run_metadata)
#    1172       except _PREEMPTION_ERRORS as e:
#    1173         logging.info('An error was raised. This may be due to a preemption in '
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1253   def run(self, *args, **kwargs):
#    1254     try:
# -> 1255       return self._sess.run(*args, **kwargs)
#    1256     except _PREEMPTION_ERRORS:
#    1257       raise
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py in run(self, fetches, feed_dict, options, run_metadata)
#    1325                                   feed_dict=feed_dict,
#    1326                                   options=options,
# -> 1327                                   run_metadata=run_metadata)
#    1328
#    1329     for hook in self._hooks:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/monitored_session.py in run(self, *args, **kwargs)
#    1089
#    1090   def run(self, *args, **kwargs):
# -> 1091     return self._sess.run(*args, **kwargs)
#    1092
#    1093   def run_step_fn(self, step_fn, raw_session, run_with_hooks):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# # 평가 하기

# %%
eval_result = classifier.evaluate(input_fn=lambda:data.eval_input_fn(
    eval_input_enc, eval_output_dec, eval_target_dec,  DEFINES.batch_size))
print('\nEVAL set accuracy: {accuracy:0.3f}\n'.format(**eval_result))

# %% [markdown]
# # 테스트 하기

# %%
# 테스트용 데이터 만드는 부분이다.
# 인코딩 부분 만든다.
predic_input_enc, predic_input_enc_length = data.enc_processing(["가끔 궁금해"], char2idx)
# 학습 과정이 아니므로 디코딩 입력은 
# 존재하지 않는다.(구조를 맞추기 위해 넣는다.)
predic_output_dec, predic_output_decLength = data.dec_input_processing([""], char2idx)       
# 학습 과정이 아니므로 디코딩 출력 부분도 
# 존재하지 않는다.(구조를 맞추기 위해 넣는다.)
predic_target_dec = data.dec_target_processing([""], char2idx)      

# 예측을 하는 부분이다.
predictions = classifier.predict(
    input_fn=lambda:data.eval_input_fn(predic_input_enc, predic_output_dec, predic_target_dec, DEFINES.batch_size))

# 예측한 값을 인지 할 수 있도록 
# 텍스트로 변경하는 부분이다.
data.pred2string(predictions, idx2char)
